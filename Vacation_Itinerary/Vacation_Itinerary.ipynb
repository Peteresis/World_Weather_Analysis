# %% [markdown]
# ## Module 6 Challenge - Deliverable 3
# ## Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID         City Country  Max Temp Current Description      Lat  \
# 0        1  Port Alfred      ZA     73.72           clear sky -33.5906
# 1        3   Malmesbury      ZA     71.78           clear sky -33.4608
# 2        4      Rikitea      PF     79.41          light rain -23.1203
# 3        6   Bloomfield      US     57.97           clear sky  40.8068
# 4       10         Lebu      CL     60.51           clear sky -37.6167
#
#         Lng           Hotel Name
# 0   26.8910   The Halyards Hotel
# 1   18.7271  SuNel's Guest Rooms
# 2 -134.9692      People ThankYou
# 3  -74.1854         Troy Carroll
# 4  -73.6500     Hostal Las Lilas

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
pd.set_option('display.max_rows', None)
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
print(vacation_df)
# Out:
#      City_ID                       City Country  Max Temp  \
# 0          1                Port Alfred      ZA     73.72
# 1          3                 Malmesbury      ZA     71.78
# 2          4                    Rikitea      PF     79.41
# 3          6                 Bloomfield      US     57.97
# 4         10                       Lebu      CL     60.51
# 5         11                 Bredasdorp      ZA     68.95
# 6         13                     Hobart      AU     55.26
# 7         22                    Ushuaia      AR     51.42
# 8         23              Ponta Delgada      PT     63.32
# 9         24                       Lata      PT     56.80
# 10        25                       Hilo      US     73.62
# 11        26                    Mataura      NZ     52.86
# 12        28                   Ucluelet      CA     50.31
# 13        29                     Padang      ID     77.11
# 14        30                  Busselton      AU     54.54
# 15        31               Constitucion      CL     65.23
# 16        32  San Bartolome De Tirajana      ES     59.47
# 17        33                  Cape Town      ZA     73.11
# 18        35                     Atuona      PF     78.98
# 19        37             Ribeira Grande      PT     63.00
# 20        38              Florianopolis      BR     75.63
# 21        44                  Geraldton      AU     61.21
# 22        45                     Mehran      IR     67.23
# 23        49               Richards Bay      ZA     71.91
# 24        50                East London      ZA     74.34
# 25        51                  Coihaique      CL     61.41
# 26        52                  Inhambane      MZ     76.98
# 27        57             Port Elizabeth      ZA     71.31
# 28        58                      Bluff      NZ     57.13
# 29        59                      Lagoa      PT     58.84
# 30        63                     Castro      BR     73.96
# 31        66               Saint George      US     61.79
# 32        67                 Codrington      AU     56.84
# 33        68                  Gorontalo      ID     75.25
# 34        69                   Chiredzi      ZW     69.46
# 35        70                  Carnarvon      AU     77.07
# 36        71         Comodoro Rivadavia      AR     67.86
# 37        73                      Vaini      TO     78.96
# 38        76              Mar Del Plata      AR     73.87
# 39        79                    Mayumba      GA     79.83
# 40        83                      Kimbe      PG     75.52
# 41        84               Punta Arenas      CL     53.71
# 42        85               Kruisfontein      ZA     68.88
# 43        86                     Rovinj      HR     53.42
# 44        89                     Kailua      US     74.14
# 45        94                   Portland      US     58.28
# 46        95                   Bengkulu      ID     76.24
# 47        96                     Nangka      PH     78.80
# 48        98                      Along      IN     65.28
# 49       100                  Esperance      AU     58.84
# 128      319                    Huarmey      PE     76.28
# 129      324               General Roca      AR     79.63
# 130      326                 Willowmore      ZA     74.14
# 131      327                    Nampula      MZ     76.95
# 132      329                     Tandil      AR     78.89
# 133      331             Port Macquarie      AU     59.90
# 134      333                  Ruiselede      BE     62.46
# 135      334                     Lipari      IT     54.21
# 136      335                 Bagotville      AU     63.86
# 137      338               Port Augusta      AU     64.15
# 138      340                  Le Pradet      FR     54.37
# 139      343                    Malanje      AO     65.91
# 140      344                     Marawi      PH     68.07
# 141      347                    Northam      GB     54.66
# 142      351                 Luganville      VU     78.06
# 143      353                Andros Town      BS     78.76
# 144      355                   Paracuru      BR     79.11
# 145      359                   Marshall      US     76.08
# 146      361                        Vao      NC     75.87
# 147      363                    Sambava      MG     78.33
# 148      365                    Ojinaga      MX     58.57
# 149      367                   Trancoso      MX     68.11
# 150      371                   Victoria      HK     74.97
# 151      372                    Mareeba      AU     66.92
# 152      374                  Ewa Beach      US     74.70
# 153      378                      Rocha      UY     70.99
# 154      383                   Goodyear      US     77.32
# 155      384                       Chuy      UY     72.95
# 156      386                    Ballina      AU     64.02
# 157      389                     Jiwani      PK     75.72
# 158      391                     Omboue      GA     79.79
# 159      393                  Sinnamary      GF     79.23
# 160      394                       Naze      JP     59.92
# 161      396                      Asosa      ET     76.87
# 162      397                        Gat      IL     54.28
# 163      398                    Copiapo      CL     65.89
# 164      401                  Greenwood      US     74.07
# 165      402                    Laviana      ES     61.74
# 166      404                     Itoman      JP     66.22
# 167      407                       Gien      FR     57.29
# 168      408                  Srandakan      ID     77.27
# 169      409                      Pisco      PE     75.25
# 170      410              Central Point      US     58.50
# 171      411                    Cascais      PT     57.02
# 172      414                   San Luis      AR     79.27
# 173      415                 Hambantota      LK     79.39
# 174      416                     Aviles      ES     65.17
# 175      418                    Ternate      ID     76.15
# 176      421                     Hirara      JP     70.90
# 177      423                    Fortuna      US     50.92
# 178      428                     Lompoc      US     78.85
# 179      429                 Sangmelima      CM     79.92
# 180      430            Puerto Princesa      PH     79.05
# 181      432                       Esna      EG     64.42
# 182      434                   Menongue      AO     65.59
# 183      438                 Nouadhibou      MR     69.78
# 184      441                    Labuhan      ID     79.74
# 185      442                    Torring      DK     50.11
# 186      443                   Galesong      ID     75.22
# 187      448                      Naron      ES     60.03
# 188      449                     Madang      PG     75.27
# 189      456            Charters Towers      AU     67.39
# 190      459                   Sri Aman      MY     75.25
# 191      460               Komsomolskiy      UZ     50.72
# 192      467                  Maldonado      UY     74.23
# 193      469                     Wanaka      NZ     53.11
# 194      474                   Bardiyah      LY     51.84
# 195      480                   Belmonte      BR     79.25
# 196      482                    Morbach      DE     54.10
# 197      490                     Ermelo      ZA     57.04
# 198      491                        Sur      OM     78.51
# 199      494                   Necochea      AR     77.58
# 200      495                       Daru      PG     77.79
# 201      496                     Bugene      TZ     57.63
# 202      500                  Mount Isa      AU     69.57
# 203      502                  Marrakesh      MA     69.87
# 204      503                    Ahipara      NZ     63.63
# 205      507          Sao Joao Da Barra      BR     77.09
# 206      508                     Sampit      ID     73.42
# 286      710                    Butembo      CD     57.54
# 287      711              Pacific Grove      US     75.58
# 288      712               Marsa Matruh      EG     53.08
# 289      714                      Evans      US     76.23
#
#       Current Description      Lat       Lng  \
# 0               clear sky -33.5906   26.8910
# 1               clear sky -33.4608   18.7271
# 2              light rain -23.1203 -134.9692
# 3               clear sky  40.8068  -74.1854
# 4               clear sky -37.6167  -73.6500
# 5           broken clouds -34.5322   20.0403
# 6         overcast clouds -42.8794  147.3294
# 7           broken clouds -54.8000  -68.3000
# 8        scattered clouds  37.7333  -25.6667
# 9              light rain  40.1629   -8.3327
# 10       scattered clouds  19.7297 -155.0900
# 11              clear sky -46.1927  168.8643
# 12        overcast clouds  48.9329 -125.5528
# 13             light rain  -0.9492  100.3543
# 14              clear sky -33.6500  115.3333
# 15              clear sky -35.3333  -72.4167
# 16             few clouds  27.9248  -15.5733
# 17              clear sky -33.9258   18.4232
# 18        overcast clouds  -9.8000 -139.0333
# 19             few clouds  38.5167  -28.7000
# 20          broken clouds -27.6146  -48.5012
# 21              clear sky -28.7667  114.6000
# 22              clear sky  33.1222   46.1646
# 23             few clouds -28.7830   32.0377
# 24              clear sky -33.0153   27.9116
# 25          broken clouds -45.5752  -72.0662
# 26          broken clouds -23.8650   35.3833
# 27              clear sky -33.9180   25.5701
# 28              clear sky -46.6000  168.3333
# 29          broken clouds  39.0500  -27.9833
# 30       scattered clouds -24.7911  -50.0119
# 31              clear sky  37.1041 -113.5841
# 32          broken clouds -38.2667  141.9667
# 33        overcast clouds   0.5412  123.0595
# 34          broken clouds -21.0500   31.6667
# 35        overcast clouds -24.8667  113.6333
# 36              clear sky -45.8667  -67.5000
# 37        overcast clouds -21.2000 -175.2000
# 38       scattered clouds -38.0023  -57.5575
# 39        overcast clouds  -3.4320   10.6554
# 40             light rain  -5.5502  150.1429
# 41              clear sky -53.1500  -70.9167
# 42              clear sky -34.0033   24.7314
# 43              clear sky  45.0800   13.6400
# 44        overcast clouds  21.4022 -157.7394
# 45        overcast clouds  45.5234 -122.6762
# 46          broken clouds  -3.8004  102.2655
# 47          broken clouds   9.4006  122.8169
# 48       scattered clouds  28.1667   94.7667
# 49        overcast clouds -33.8667  121.9000
# 50        overcast clouds   1.1667  108.9667
# 51              clear sky  38.4210 -121.4238
# 52             light rain -31.9500  141.4333
# 53             few clouds -23.7000  133.8833
# 54        overcast clouds  39.1834  -84.5333
# 55          moderate rain -12.3833   16.9333
# 56       scattered clouds -34.4187   19.2345
# 57              clear sky  14.8961  -24.4956
# 58          broken clouds  32.6667  -17.1000
# 59          broken clouds  34.8791  -76.9013
# 60              clear sky -24.5333   32.9833
# 61          broken clouds -42.7826  147.0587
# 62              clear sky  52.4443   15.1168
# 63              clear sky  46.7958   11.9364
# 64              clear sky  24.6333 -101.4167
# 65              clear sky  41.3712  -73.4140
# 66       scattered clouds  14.9215  -23.5087
# 67             few clouds  20.8947 -156.4700
# 68          broken clouds -34.7333  135.8667
# 69             few clouds -21.2078 -159.7750
# 70              clear sky  51.3813    1.3862
# 71             few clouds   6.8837  116.8477
# 72              clear sky -30.1811  -50.2056
# 73          broken clouds  37.7167  -25.4333
# 74          moderate rain  22.0752 -159.3190
# 75             light rain -37.8811  147.9810
# 76          broken clouds  27.3747   87.2039
# 77        overcast clouds  -6.2167  155.6333
# 78        overcast clouds   9.9658   98.6348
# 79       scattered clouds -23.3156  -46.2214
# 80              clear sky  24.0934   32.9070
# 81             few clouds  25.5198   90.2201
# 82              clear sky -29.9533  -71.3436
# 83              clear sky  28.0170  -97.5169
# 84          broken clouds  24.3448  124.1572
# 85              clear sky   5.3505   48.5268
# 86          broken clouds  23.4833 -103.8833
# 87        overcast clouds   1.6381   18.0667
# 88             few clouds -17.7125  -39.2481
# 89              clear sky  29.9697   40.2064
# 90        overcast clouds -35.3500  150.4667
# 91             few clouds  38.7333  -27.0667
# 92              clear sky  27.9769 -114.0611
# 93             few clouds -29.7833  151.1167
# 94        overcast clouds  30.3088  -89.3300
# 95        overcast clouds  43.2686   -7.5406
# 96             few clouds  37.3394 -121.8950
# 97        overcast clouds  -9.1061  124.8925
# 98          moderate rain -32.8167  -56.5167
# 99        overcast clouds  26.1842  127.7558
# 100            light rain -19.5500  169.2667
# 101      scattered clouds -16.2325   39.9086
# 102       overcast clouds  28.8724  105.4405
# 103         broken clouds  14.0453  124.1694
# 104             clear sky  48.8500    2.4333
# 105             clear sky  28.9167   79.9667
# 106             clear sky  17.0151   54.0924
# 107       overcast clouds  -7.9500  110.2833
# 108       overcast clouds  -2.5447   14.7533
# 109             clear sky  48.8145    3.0850
# 110             clear sky  47.4504    8.5299
# 111         moderate rain   4.9333  -52.3333
# 112            few clouds -46.2817  169.8464
# 113         broken clouds  12.4497  125.2886
# 114         broken clouds  10.9333  108.1000
# 115            light rain -41.8697  -73.8203
# 116      scattered clouds  18.3333  105.9000
# 117         broken clouds   7.1333   40.7000
# 118       overcast clouds  -9.6567  120.2641
# 119       overcast clouds -20.3297  -40.2925
# 120         broken clouds   6.0667  121.0667
# 121             clear sky  32.3502  -85.1999
# 122            light rain   5.3848   95.9609
# 123             clear sky -45.4167  167.7167
# 124             clear sky -46.1333  167.6833
# 125             clear sky  21.4267   39.8261
# 126      scattered clouds  57.4667   -1.7833
# 127                  mist  11.6667   92.7500
# 128             clear sky -10.0681  -78.1522
# 129      scattered clouds -39.0333  -67.5833
# 130             clear sky -33.2926   23.4895
# 131             clear sky -15.1165   39.2666
# 132             clear sky -37.3217  -59.1332
# 133         broken clouds -31.4333  152.9167
# 134             clear sky  51.0572    3.3788
# 135             clear sky  38.4674   14.9540
# 136             clear sky -28.9833  153.4167
# 137            few clouds -32.5000  137.7667
# 138             clear sky  43.1066    6.0172
# 139         moderate rain  -9.5402   16.3410
# 140       overcast clouds   7.9986  124.2928
# 141      scattered clouds  51.0333   -4.2167
# 142       overcast clouds -15.5333  167.1667
# 143         broken clouds  24.7000  -77.7667
# 144      scattered clouds  -3.4100  -39.0306
# 145      scattered clouds  34.3834  -86.3333
# 146         broken clouds -22.6667  167.4833
# 147         broken clouds -14.2667   50.1667
# 148       overcast clouds  29.5667 -104.4167
# 149      scattered clouds  22.7333 -102.3667
# 150         moderate rain  22.2855  114.1577
# 151      scattered clouds -17.0000  145.4333
# 152            few clouds  21.3156 -158.0072
# 153         moderate rain -34.4833  -54.3333
# 154      scattered clouds  33.4353 -112.3582
# 155  heavy intensity rain -33.6971  -53.4616
# 156             clear sky -28.8667  153.5667
# 157             clear sky  25.0500   61.7417
# 158       overcast clouds  -1.5746    9.2618
# 159         broken clouds   5.3833  -52.9500
# 160       overcast clouds  28.3667  129.4833
# 161         broken clouds  10.0667   34.5333
# 162            few clouds  31.6100   34.7642
# 163             clear sky -27.3667  -70.3333
# 164         broken clouds  34.1668  -82.1165
# 165         broken clouds  43.2333   -5.5333
# 166       overcast clouds  26.1247  127.6694
# 167             clear sky  47.6933    2.6309
# 168       overcast clouds  -7.9386  110.2506
# 169             clear sky -13.7000  -76.2167
# 170      scattered clouds  42.3760 -122.9164
# 171                  mist  38.6979   -9.4215
# 172            few clouds -33.2950  -66.3356
# 173         broken clouds   6.1241   81.1185
# 174      scattered clouds  43.5547   -5.9248
# 175         moderate rain   0.8000  127.4000
# 176       overcast clouds  24.8000  125.2833
# 177             clear sky  40.5982 -124.1573
# 178            few clouds  34.6391 -120.4579
# 179       overcast clouds   2.9333   11.9833
# 180      scattered clouds   9.7392  118.7353
# 181             clear sky  25.2934   32.5540
# 182         broken clouds -14.6585   17.6910
# 183                  sand  20.9310  -17.0347
# 184       overcast clouds  -6.8844  112.2051
# 185            few clouds  55.8500    9.4833
# 186       overcast clouds  -5.3166  119.3661
# 187       overcast clouds  43.5167   -8.1528
# 188       overcast clouds  -5.2246  145.7966
# 189            few clouds -20.1000  146.2667
# 190       overcast clouds   1.2376  111.4621
# 191                  mist  40.4272   71.7189
# 192       overcast clouds -34.6667  -54.9167
# 193            few clouds -44.7000  169.1500
# 194      scattered clouds  31.7561   25.0865
# 195         broken clouds -15.8631  -38.8828
# 196             clear sky  49.8167    7.1167
# 197       overcast clouds -26.5333   29.9833
# 198             clear sky  22.5667   59.5289
# 199             clear sky -38.5473  -58.7368
# 200       overcast clouds  -9.0763  143.2092
# 201         broken clouds  -1.5911   31.1403
# 202            light rain -20.7333  139.5000
# 203      scattered clouds  31.6315   -8.0083
# 204            few clouds -35.1667  173.1667
# 205         broken clouds -21.6403  -41.0511
# 206            light rain  -2.5333  112.9500
# 207            few clouds  42.1584  -72.3287
# 208      scattered clouds -17.6167  -66.0167
# 209             clear sky -11.0964  -77.6139
# 210       overcast clouds -23.3500   47.6000
# 211             clear sky  14.6937  -17.4441
# 212      scattered clouds  31.5917   54.4318
# 213            few clouds  21.3469 -158.0858
# 214       overcast clouds  34.4166  -79.3712
# 215       overcast clouds -12.4970  131.0470
# 216       overcast clouds  20.8624   92.3058
# 217       overcast clouds  34.2610   -6.5802
# 218             clear sky  25.2088   64.6357
# 219       overcast clouds -19.0595 -169.9187
# 220             clear sky -23.7167   44.3833
# 221         broken clouds  31.4451   12.9801
# 222  heavy intensity rain  -3.9450  122.4989
# 223       overcast clouds  47.6740 -122.1215
# 224             clear sky  50.6848   14.6452
# 225                  haze  37.4636 -122.4286
# 226             clear sky -28.6500  153.6167
# 227         moderate rain  38.6103  -89.3726
# 228            few clouds  38.7666 -120.5177
# 229         broken clouds  -8.7676  160.7034
# 230      scattered clouds  42.1668  -71.2495
# 231             clear sky  32.0724  -84.2327
# 232         broken clouds -21.3667   55.6167
# 233       overcast clouds -14.9003   50.2788
# 234             clear sky -33.0393  -71.6273
# 235         broken clouds   1.8911   33.9661
# 236            few clouds  21.3906 -158.1547
# 237       overcast clouds  41.5388   -8.6151
# 238             clear sky  48.3833   -4.6167
# 239         broken clouds -18.9186  -48.2772
# 240             clear sky  29.1268   15.9477
# 241             clear sky  26.5412  -77.0636
# 242            few clouds  13.7667  109.2333
# 243      scattered clouds  19.9103  109.6859
# 244            light rain   7.0805   -2.1697
# 245       overcast clouds  -4.3167   20.5833
# 246             clear sky -33.7576   25.3971
# 247             clear sky  50.8516   -1.1793
# 248             clear sky  27.7523  -98.0697
# 249      scattered clouds  23.8000 -100.7333
# 250            light rain  -5.1036   30.3911
# 251       overcast clouds  -6.1333   24.4833
# 252            few clouds -23.8500  151.2500
# 253         broken clouds  24.0333   84.0667
# 254       overcast clouds -34.3000  -57.2333
# 255         broken clouds -16.5000  -68.1500
# 256       overcast clouds -11.6066   34.2907
# 257             clear sky  48.4044    2.6903
# 258             clear sky -35.8500  -71.6000
# 259         broken clouds  -1.6000  103.6167
# 260         broken clouds  -3.4667  102.5333
# 261             clear sky -21.4833   27.4833
# 262         broken clouds -23.6678  -46.4614
# 263            few clouds   1.5500  110.3333
# 264       overcast clouds -32.7167  152.1500
# 265             clear sky  21.6422   69.6093
# 266       overcast clouds  33.1385  -95.6011
# 267            light rain  -3.6667  152.4333
# 268             clear sky  50.1000    1.8333
# 269       overcast clouds  -5.0892  -81.1144
# 270             clear sky  53.4106   -2.9779
# 271            few clouds  28.4962   30.8029
# 272         moderate rain  20.4500  106.3333
# 273         broken clouds  10.9995  122.6711
# 274      scattered clouds  37.8060   -8.6715
# 275      scattered clouds  29.0605  -13.5640
# 276             clear sky  28.4008  -97.7483
# 277       overcast clouds  -3.3667  135.4833
# 278            few clouds -16.9167  145.7667
# 279       overcast clouds -12.2333  136.7667
# 280             clear sky -20.0167  148.2333
# 281       overcast clouds  53.5237   -2.4935
# 282      scattered clouds  28.6585  -17.9182
# 283            light rain -26.9566   24.7284
# 284             clear sky  44.0000   -0.6667
# 285       overcast clouds  -1.1950  -46.0200
# 286       overcast clouds   0.1500   29.2833
# 287            few clouds  36.6177 -121.9166
# 288            few clouds  31.3525   27.2453
# 289         broken clouds  33.5337  -82.1307
#
#                                             Hotel Name
# 0                                   The Halyards Hotel
# 1                                  SuNel's Guest Rooms
# 2                                      People ThankYou
# 3                                         Troy Carroll
# 4                                     Hostal Las Lilas
# 5                             Bredasdorp Country Manor
# 6                St Ives Hobart Accommodation Tasmania
# 7                                      Albatross Hotel
# 8                                      Vila Nova Hotel
# 9                                          Casa Maquia
# 10                                 Hilo Hawaiian Hotel
# 11                                       Ellie's Villa
# 270  Premier Inn Liverpool City Centre (Moorfields)...
# 271         Link Co-Working space & Development center
# 272                                       Sweden Hotel
# 273                                    SEGAYA PROPERTY
# 274                                  Herdade Baia Baia
# 275                           B&B La Casona de Nazaret
# 276  Holiday Inn Express & Suites Beeville, an IHG ...
# 277                             Hotel Nusantara Nabire
# 278                              Mantra Trilogy Cairns
# 279                            East Arnhem Real Estate
# 280                           Castle Motor Lodge Motel
# 281                                  The Mercury Motel
# 282                                      Valle Aridane
# 283                            The Times Premier Lodge
# 284                                    Le moulin vieux
# 285                                             Lidera
# 286                                      Hotel Butembo
# 287                                   Lovers Point Inn
# 288                                          Beau Site
# 289                                     Evans hide out

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
# 4b. Display the figure
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # 4a. Add a marker layer for each city to the map.
#       2 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# ----> 3 markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       4 fig.add_layer(markers)
#       5 # 4b. Display the figure
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\marker.py:553, in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     485 @doc_subst(_doc_snippets)
#     486 def marker_layer(
#     487         locations, hover_text='', label='',
#     488         info_box_content=None, display_info_box=None):
#     489     """
#     490     Marker layer
#     491
#    (...)
#     551         A :class:`gmaps.Markers` instance.
#     552     """
# --> 553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\marker.py:311, in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     309 if is_atomic(label):
#     310     label = [label] * number_markers
# --> 311 if is_atomic(info_box_content):
#     312     info_box_content = [info_box_content] * number_markers
#     314 marker_options = {
#     315     'location': locations_to_list(locations),
#     316     'hover_text': hover_text,
#     317     'label': label
#     318 }
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\options.py:40, in is_atomic(elem)
#      34 def is_atomic(elem):
#      35     """
#      36     True if an element is a single atom and false if it's a collection
#      37     """
#      38     return (
#      39         isinstance(elem, string_types) or
# ---> 40         not isinstance(elem, collections.Iterable)
#      41     )
#
# AttributeError: module 'collections' has no attribute 'Iterable'

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Ushuaia"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Ushuaia"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Comodoro Rivadavia"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Mar Del Plata"]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "San Luis"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end], ignore_index=True)
itinerary_df
# Out:
#    City_ID                City Country  Max Temp Current Description      Lat  \
# 0       22             Ushuaia      AR     51.42       broken clouds -54.8000
# 1       71  Comodoro Rivadavia      AR     67.86           clear sky -45.8667
# 2       76       Mar Del Plata      AR     73.87    scattered clouds -38.0023
# 3      414            San Luis      AR     79.27          few clouds -33.2950
# 4       22             Ushuaia      AR     51.42       broken clouds -54.8000
#
#        Lng                Hotel Name
# 0 -68.3000           Albatross Hotel
# 1 -67.5000             Austral Hotel
# 2 -57.5575  Gran Hotel Mar del Plata
# 3 -66.3356             Huarpes Hotel
# 4 -68.3000           Albatross Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#       2 locations = itinerary_df[["Lat", "Lng"]]
#       3 fig = gmaps.figure()
# ----> 4 marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       5 fig.add_layer(marker_layer)
#       7 # 11b. Display the figure
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\marker.py:553, in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     485 @doc_subst(_doc_snippets)
#     486 def marker_layer(
#     487         locations, hover_text='', label='',
#     488         info_box_content=None, display_info_box=None):
#     489     """
#     490     Marker layer
#     491
#    (...)
#     551         A :class:`gmaps.Markers` instance.
#     552     """
# --> 553     marker_options = _marker_layer_options(
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\marker.py:311, in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     309 if is_atomic(label):
#     310     label = [label] * number_markers
# --> 311 if is_atomic(info_box_content):
#     312     info_box_content = [info_box_content] * number_markers
#     314 marker_options = {
#     315     'location': locations_to_list(locations),
#     316     'hover_text': hover_text,
#     317     'label': label
#     318 }
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\gmaps\options.py:40, in is_atomic(elem)
#      34 def is_atomic(elem):
#      35     """
#      36     True if an element is a single atom and false if it's a collection
#      37     """
#      38     return (
#      39         isinstance(elem, string_types) or
# ---> 40         not isinstance(elem, collections.Iterable)
#      41     )
#
# AttributeError: module 'collections' has no attribute 'Iterable'
